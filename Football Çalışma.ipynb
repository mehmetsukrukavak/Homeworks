# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


df = pd.read_csv("data/Football_Players/results.csv")
df.head()
# Out:
#          date home_team away_team  home_score  away_score tournament     city  \
# 0  1872-11-30  Scotland   England           0           0   Friendly  Glasgow
# 1  1873-03-08   England  Scotland           4           2   Friendly   London
# 2  1874-03-07  Scotland   England           2           1   Friendly  Glasgow
# 3  1875-03-06   England  Scotland           2           2   Friendly   London
# 4  1876-03-04  Scotland   England           3           0   Friendly  Glasgow
#
#     country  neutral
# 0  Scotland    False
# 1   England    False
# 2  Scotland    False
# 3   England    False
# 4  Scotland    False

# %%
df["tournament"].unique()
# Out:
# array(['Friendly', 'British Home Championship', 'Évence Coppée Trophy',
#        'Muratti Vase', 'Copa Lipton', 'Copa Newton',
#        'Copa Premio Honor Argentino', 'Olympic Games',
#        'Copa Premio Honor Uruguayo', 'Far Eastern Championship Games',
#        'Copa Roca', 'Copa América', 'Inter-Allied Games', 'Peace Cup',
#        'Open International Championship', 'Copa Chevallier Boutell',
#        'Nordic Championship', 'Central European International Cup',
#        'Baltic Cup', 'Balkan Cup', 'Central American and Caribbean Games',
#        'FIFA World Cup', 'Copa Rio Branco',
#        'FIFA World Cup qualification', 'Bolivarian Games',
#        'CCCF Championship', 'NAFC Championship', 'Copa Oswaldo Cruz',
#        'Asian Games', 'Pan American Championship', 'Copa del Pacífico',
#        "Copa Bernardo O'Higgins", 'AFC Asian Cup qualification',
#        'Atlantic Cup', 'AFC Asian Cup', 'African Cup of Nations',
#        'Copa Paz del Chaco', 'Merdeka Tournament',
# ...

# %%
df.isnull().sum()
# Out:
# date          0
# home_team     0
# away_team     0
# home_score    0
# away_score    0
# tournament    0
# city          0
# country       0
# neutral       0
# dtype: int64

# %%
df.describe()
# Out:
#          home_score    away_score
# count  48335.000000  48335.000000
# mean       1.758477      1.181194
# std        1.773333      1.400151
# min        0.000000      0.000000
# 25%        1.000000      0.000000
# 50%        1.000000      1.000000
# 75%        2.000000      2.000000
# max       31.000000     21.000000

# %%
df["home_score"].max(), df["away_score"].max()
# Out:
# (np.int64(31), np.int64(21))

# %%
df[df["home_score"] == 31]
# Out:
#              date  home_team       away_team  home_score  away_score  \
# 25418  2001-04-11  Australia  American Samoa          31           0
#
#                          tournament           city    country  neutral
# 25418  FIFA World Cup qualification  Coffs Harbour  Australia    False

# %%
df[df["away_score"] == 21]
# Out:
#              date home_team    away_team  home_score  away_score  \
# 29038  2005-03-11      Guam  North Korea           0          21
#
#               tournament    city country  neutral
# 29038  EAFF Championship  Taipei  Taiwan     True

# %%
sns.pairplot(df)

# %%
df.head()
# Out:
#          date home_team away_team  home_score  away_score tournament     city  \
# 0  1872-11-30  Scotland   England           0           0   Friendly  Glasgow
# 1  1873-03-08   England  Scotland           4           2   Friendly   London
# 2  1874-03-07  Scotland   England           2           1   Friendly  Glasgow
# 3  1875-03-06   England  Scotland           2           2   Friendly   London
# 4  1876-03-04  Scotland   England           3           0   Friendly  Glasgow
#
#     country  neutral
# 0  Scotland    False
# 1   England    False
# 2  Scotland    False
# 3   England    False
# 4  Scotland    False

# %%
df_world_cup = df[df["tournament"]== 'FIFA World Cup']

# %%
df_world_cup.isnull().sum()
# Out:
# date          0
# home_team     0
# away_team     0
# home_score    0
# away_score    0
# tournament    0
# city          0
# country       0
# neutral       0
# dtype: int64

# %%
df_world_cup.head()
# Out:
#             date  home_team      away_team  home_score  away_score  \
# 1486  1930-07-13    Belgium  United States           0           3
# 1487  1930-07-13     France         Mexico           4           1
# 1488  1930-07-14     Brazil     Yugoslavia           1           2
# 1489  1930-07-14       Peru        Romania           1           3
# 1490  1930-07-15  Argentina         France           1           0
#
#           tournament        city  country  neutral
# 1486  FIFA World Cup  Montevideo  Uruguay     True
# 1487  FIFA World Cup  Montevideo  Uruguay     True
# 1488  FIFA World Cup  Montevideo  Uruguay     True
# 1489  FIFA World Cup  Montevideo  Uruguay     True
# 1490  FIFA World Cup  Montevideo  Uruguay     True

# %%
df_world_cup.describe()
# Out:
#        home_score  away_score
# count  964.000000  964.000000
# mean     1.567427    1.254149
# std      1.493710    1.298107
# min      0.000000    0.000000
# 25%      0.000000    0.000000
# 50%      1.000000    1.000000
# 75%      2.000000    2.000000
# max     10.000000    8.000000

# %%
df2 = pd.read_csv("data/Football_Players/goalscorers.csv")

# %%
df2.head()
# Out:
#          date  home_team away_team       team            scorer  minute  \
# 0  1916-07-02      Chile   Uruguay    Uruguay   José Piendibene    44.0
# 1  1916-07-02      Chile   Uruguay    Uruguay  Isabelino Gradín    55.0
# 2  1916-07-02      Chile   Uruguay    Uruguay  Isabelino Gradín    70.0
# 3  1916-07-02      Chile   Uruguay    Uruguay   José Piendibene    75.0
# 4  1916-07-06  Argentina     Chile  Argentina     Alberto Ohaco     2.0
#
#    own_goal  penalty
# 0     False    False
# 1     False    False
# 2     False    False
# 3     False    False
# 4     False    False

# %%
df2[((df2.home_team =="Turkey") | (df2.away_team =="Turkey") & (df2.penalty == False))]
# Out:
#              date       home_team away_team            team  \
# 136    1924-05-25  Czechoslovakia    Turkey  Czechoslovakia
# 137    1924-05-25  Czechoslovakia    Turkey  Czechoslovakia
# 138    1924-05-25  Czechoslovakia    Turkey  Czechoslovakia
# 139    1924-05-25  Czechoslovakia    Turkey          Turkey
# 140    1924-05-25  Czechoslovakia    Turkey  Czechoslovakia
# ...           ...             ...       ...             ...
# 44318  2024-07-02         Austria    Turkey          Turkey
# 44319  2024-07-02         Austria    Turkey         Austria
# 44342  2024-07-06     Netherlands    Turkey          Turkey
# 44343  2024-07-06     Netherlands    Turkey     Netherlands
# 44344  2024-07-06     Netherlands    Turkey     Netherlands
#
#                     scorer  minute  own_goal  penalty
# 136           Rudolf Sloup    21.0     False    False
# 137         Josef Sedláček    28.0     False    False
# 138         Josef Sedláček    37.0     False    False
# ...

# %%
df3 = pd.read_csv("data/Football_Players/shootouts.csv")

# %%
df3.head()
# Out:
#          date    home_team         away_team       winner first_shooter
# 0  1967-08-22        India            Taiwan       Taiwan           NaN
# 1  1971-11-14  South Korea  Vietnam Republic  South Korea           NaN
# 2  1972-05-07  South Korea              Iraq         Iraq           NaN
# 3  1972-05-17     Thailand       South Korea  South Korea           NaN
# 4  1972-05-19     Thailand          Cambodia     Thailand           NaN

# %%
sns.pairplot(df3)
df3.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 sns.pairplot(df3)
#       2 df3.head()
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/seaborn/axisgrid.py:2119, in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2117 # Set up the PairGrid
#    2118 grid_kws.setdefault("diag_sharey", diag_kind == "hist")
# -> 2119 grid = PairGrid(data, vars=vars, x_vars=x_vars, y_vars=y_vars, hue=hue,
#    2120                 hue_order=hue_order, palette=palette, corner=corner,
#    2121                 height=height, aspect=aspect, dropna=dropna, **grid_kws)
#    2123 # Add the markers here as PairGrid has figured out how many levels of the
# ...
